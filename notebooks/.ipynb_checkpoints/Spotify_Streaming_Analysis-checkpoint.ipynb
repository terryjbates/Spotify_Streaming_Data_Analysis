# %% [markdown]
# # Library Import

# %%
import sys
import os
import base64
import pandas as pd
import numpy as np
import json
import re
import requests
import psycopg2
import time

from sqlalchemy import create_engine, text, Table, Column, Integer, String, MetaData, insert
from sqlalchemy import select
from pathlib import Path, PureWindowsPath, PurePosixPath, PurePath
from dotenv import load_dotenv

from IPython.display import display, JSON

# %% [markdown]
# # Data Load

# %%
os.chdir('C:\\Users\\lover\\Documents\\Github\\Spotify_Streaming_Data_Analysis\\')

os.getcwd()
# Out:
# 'C:\\Users\\lover\\Documents\\Github\\Spotify_Streaming_Data_Analysis'

# %%
# Set data directory
# DATA_DIR = r"\data\text\db_archive"

# Construct data directory path

# Get current path
cwd = PurePath(Path.cwd())

# Construct path to archive location
data_path = cwd / 'data' / 'spotify_data' / 'Spotify Extended Streaming History'

# %%
string_data_path = str(data_path)
string_data_path
# Out:
# 'C:\\Users\\lover\\Documents\\Github\\Spotify_Streaming_Data_Analysis\\data\\spotify_data\\Spotify Extended Streaming History'

# %%
def get_json_files(directory):
  """
  Returns a list of PurePath objects representing JSON files in the given directory.
  """
  json_files = []
  for filename in os.listdir(directory):
    file_path = PurePath(directory, filename)
    if file_path.is_file() and file_path.suffix == '.json':
      json_files.append(file_path)
  return json_files


# Method 2: Using Path.iterdir() with PurePath
def list_files_pathlib(path_str):
    pure_path = PurePath(path_str)
    path = Path(pure_path)
    if not path.is_dir():
        return "The specified path is not a directory."
    return [entry.name for entry in path.iterdir() if entry.is_file()]



# Method 1: Using os.listdir() with PurePath
def list_files_os(path_str):
    pure_path = PurePath(path_str)
    if not os.path.isdir(path_str):
        return "The specified path is not a directory."
        all_files =  [f for f in os.listdir(pure_path) 
            if os.path.isfile(os.path.join(pure_path, f)) ]
    return [f for f in os.listdir(pure_path) if os.path.isfile(os.path.join(pure_path, f))]

# %% [markdown]
# Let's first get a sense of what each record is made of. We will load one of the JSON files, sample a single record, and peruse the fields it contains.

# %%
# Obtain all the files in th 
all_files = list_files_os(data_path)

# %%
# Extract only the audio JSON files we are interested in
audio_files = all_files
for file in audio_files:
    # print(f"File is {file}")
    if not re.match('.*Audio.*json', file):
        audio_files.remove(file)

# Echo the list of audio files
audio_files
# Out:
# ['Streaming_History_Audio_2014-2017_0.json',
#  'Streaming_History_Audio_2017-2018_1.json',
#  'Streaming_History_Audio_2018-2019_2.json',
#  'Streaming_History_Audio_2019-2020_4.json',
#  'Streaming_History_Audio_2019_3.json',
#  'Streaming_History_Audio_2020-2021_5.json',
#  'Streaming_History_Audio_2021-2022_9.json',
#  'Streaming_History_Audio_2021_6.json',
#  'Streaming_History_Audio_2021_7.json',
#  'Streaming_History_Audio_2021_8.json',
#  'Streaming_History_Audio_2022-2023_12.json',
#  'Streaming_History_Audio_2022_10.json',
#  'Streaming_History_Audio_2022_11.json',
#  'Streaming_History_Audio_2023-2024_14.json',
#  'Streaming_History_Audio_2023_13.json',
#  'Streaming_History_Audio_2024-2025_17.json',
#  'Streaming_History_Audio_2024_15.json',
#  'Streaming_History_Audio_2024_16.json']

# %%
# Construct a path 
test_audio_file_path =  data_path / audio_files[0]

# Open our test file with a context manager and read the data into a Python object
with open(test_audio_file_path, 'r', encoding='utf-8', errors='ignore') as file:
    json_data= json.load(file)

# %%
json_sample = json_data[0]
json_sample
# Out:
# {'ts': '2014-02-08T08:19:05Z',
#  'platform': 'WebPlayer (websocket RFC6455)',
#  'ms_played': 345730,
#  'conn_country': 'US',
#  'ip_addr': '108.233.253.176',
#  'master_metadata_track_name': 'Get Closer',
#  'master_metadata_album_artist_name': 'Ron Basejam',
#  'master_metadata_album_album_name': 'Trax 3lLascivious SummerlSelected by Eric Pajot',
#  'spotify_track_uri': 'spotify:track:4qD4HNcdFGihp5Mn8JTgTB',
#  'episode_name': None,
#  'episode_show_name': None,
#  'spotify_episode_uri': None,
#  'audiobook_title': None,
#  'audiobook_uri': None,
#  'audiobook_chapter_uri': None,
#  'audiobook_chapter_title': None,
#  'reason_start': 'clickrow',
#  'reason_end': 'unknown',
#  'shuffle': False,
#  'skipped': False,
#  'offline': False,
#  'offline_timestamp': None,
#  'incognito_mode': False}

# %% [markdown]
# # Load Environmental Variables

# %%
# Load in environment variables
load_dotenv()
# Out:
# True

# %%
# Configure DB connection info
db_user = os.getenv("DB_USER")
db_host = os.getenv("DB_HOST")
db_name = os.getenv("DB_NAME")
db_password = os.getenv("DB_PASSWORD")
db_port = os.getenv("DB_PORT")

# %%
client_id = os.getenv("CLIENT_ID")
client_secret = os.getenv("CLIENT_SECRET")

# %%
print(db_user)
# Out:
# spotify_postgres_user

# %% [markdown]
# # Connect to Postgres Database

# %%
# Establish connection with the database
# engine = create_engine( 
#     "dialect+driver//usernam:password@hostname:portnumber/databasename") 

# stablish connection with Postgres database 
engine = create_engine( 
    f"postgresql+psycopg2://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}")

# %%
# Close the engine
engine.dispose()

# %%
with engine.connect() as conn:
    result = conn.execute(text("SELECT version() "))
    print(result.all())
# Out:
# [('PostgreSQL 17.0 on x86_64-windows, compiled by msvc-19.41.34120, 64-bit',)]

# %%
metadata_obj = MetaData()
spotify_table = Table('spotify_data', metadata_obj, autoload_with=engine)
spotify_table
# Out:
# Table('spotify_data', MetaData(), Column('id', INTEGER(), table=<spotify_data>, nullable=False, server_default=Identity(always=True, start=1, increment=1, minvalue=1, maxvalue=2147483647, cycle=False, cache=1)), Column('timestamp_column', TIMESTAMP(timezone=True), table=<spotify_data>), Column('platform', VARCHAR(length=50), table=<spotify_data>), Column('ms_played', INTEGER(), table=<spotify_data>), Column('conn_country', VARCHAR(length=2), table=<spotify_data>), Column('ip_addr', VARCHAR(length=15), table=<spotify_data>), Column('track_name', VARCHAR(length=100), table=<spotify_data>), Column('artist_name', VARCHAR(length=100), table=<spotify_data>), Column('album_name', VARCHAR(length=100), table=<spotify_data>), Column('spotify_track_uri', VARCHAR(length=50), table=<spotify_data>), Column('episode_name', VARCHAR(length=100), table=<spotify_data>), Column('episode_show_name', VARCHAR(length=100), table=<spotify_data>), Column('spotify_episode_uri', VARCHAR(length=50), table=<spotify_data>), Column('audiobook_title', VARCHAR(length=100), table=<spotify_data>), Column('audiobook_uri', VARCHAR(length=50), table=<spotify_data>), Column('audiobook_chapter_uri', VARCHAR(length=50), table=<spotify_data>), Column('audiobook_chapter_title', VARCHAR(length=100), table=<spotify_data>), Column('reason_start', VARCHAR(length=30), table=<spotify_data>), Column('reason_end', VARCHAR(length=30), table=<spotify_data>), Column('shuffle', BOOLEAN(), table=<spotify_data>, server_default=DefaultClause(<sqlalchemy.sql.elements.TextClause object at 0x0000017C0D7E53D0>, for_update=False)), Column('skipped', BOOLEAN(), table=<spotify_data>, server_default=DefaultClause(<sqlalchemy.sql.elements.TextClause object at 0x0000017C0D7E5550>, for_update=False)), Column('offline', BOOLEAN(), table=<spotify_data>, server_default=DefaultClause(<sqlalchemy.sql.elements.TextClause object at 0x0000017C0D7E5670>, for_update=False)), Column('offline_timestamp', TIMESTAMP(timezone=True), table=<spotify_data>), Column('incognito_mode', BOOLEAN(), table=<spotify_data>, server_default=DefaultClause(<sqlalchemy.sql.elements.TextClause object at 0x0000017C0D7E5730>, for_update=False)), schema=None)

# %%
# Introspect on a potential insert command
print(insert(spotify_table))
# Out:
# INSERT INTO spotify_data (id, timestamp_column, platform, ms_played, conn_country, ip_addr, track_name, artist_name, album_name, spotify_track_uri, episode_name, episode_show_name, spotify_episode_uri, audiobook_title, audiobook_uri, audiobook_chapter_uri, audiobook_chapter_title, reason_start, reason_end, shuffle, skipped, offline, offline_timestamp, incognito_mode) VALUES (:id, :timestamp_column, :platform, :ms_played, :conn_country, :ip_addr, :track_name, :artist_name, :album_name, :spotify_track_uri, :episode_name, :episode_show_name, :spotify_episode_uri, :audiobook_title, :audiobook_uri, :audiobook_chapter_uri, :audiobook_chapter_title, :reason_start, :reason_end, :shuffle, :skipped, :offline, :offline_timestamp, :incognito_mode)

# %%
# Test insert a single record
with engine.connect() as conn:
    result = conn.execute(
        insert(spotify_table),
        [{"timestamp_column": json_sample['ts'],
          "platform": json_sample['platform'],
          "ms_played": json_sample['ms_played'],
          "conn_country": json_sample['conn_country'],
          "track_name": json_sample['master_metadata_track_name'],
          "artist_name": json_sample['master_metadata_album_artist_name'],
          "album_name": json_sample['master_metadata_album_album_name'],
          "spotify_track_uri": json_sample['spotify_track_uri'],
          "episode_name": json_sample['episode_name'],
          "episode_show_name": json_sample['episode_show_name'],
          "spotify_episode_uri": json_sample['spotify_episode_uri'],
          "audiobook_title": json_sample['audiobook_title'],
          "audiobook_uri": json_sample['audiobook_uri'],
          "audiobook_chapter_uri": json_sample['audiobook_chapter_uri'],
          "audiobook_chapter_title": json_sample['audiobook_chapter_title'],
          "reason_start": json_sample['reason_start'],
          "reason_end": json_sample['reason_end'],
          "shuffle": json_sample['shuffle'],
          "skipped": json_sample['skipped'],
          "offline": json_sample['offline'],
          "offline_timestamp": json_sample['offline_timestamp'],
          "incognito_mode": json_sample['incognito_mode'],
          "ip_addr": json_sample['ip_addr'],
        }  
        ],
    )
    conn.commit()

# %%
# Test insert a truncated single record
with engine.connect() as conn:
    result = conn.execute(
        insert(spotify_table),
        [{"timestamp_column": json_sample['ts'],
          "platform": json_sample['platform'],
          "ms_played": json_sample['ms_played'],
          "conn_country": json_sample['conn_country'],
          "track_name": json_sample['master_metadata_track_name'],
          "artist_name": json_sample['master_metadata_album_artist_name'],
          "ip_addr": json_sample['ip_addr']
        }  
        ],
    )
    conn.commit()

# %%
def extract_json_from_file(json_file):
    # Open our test file with a context manager and read the data into a Python object
    with open(json_file, 'r', encoding='utf-8', errors='ignore') as input_file:
        json_data = json.load(input_file)

        # With our json_data available, open another context manager to execute insertion
        with engine.connect() as conn:
            for json_record in json_data:
                print(f"""Artist : {json_record['master_metadata_album_artist_name']} Track : {json_record['master_metadata_track_name']}\n\n
                """)
                result = conn.execute(
                    insert(spotify_table),
                    [{"timestamp_column": json_record['ts'],
                      "platform": json_record['platform'],
                      "ms_played": json_record['ms_played'],
                      "conn_country": json_record['conn_country'],
                      "track_name": json_record['master_metadata_track_name'],
                      "artist_name": json_record['master_metadata_album_artist_name'],
                      "album_name": json_record['master_metadata_album_album_name'],
                      "spotify_track_uri": json_record['spotify_track_uri'],
                      "episode_name": json_record['episode_name'],
                      "episode_show_name": json_record['episode_show_name'],
                      "spotify_episode_uri": json_record['spotify_episode_uri'],
                      "audiobook_title": json_record['audiobook_title'],
                      "audiobook_uri": json_record['audiobook_uri'],
                      "audiobook_chapter_uri": json_record['audiobook_chapter_uri'],
                      "audiobook_chapter_title": json_record['audiobook_chapter_title'],
                      "reason_start": json_record['reason_start'],
                      "reason_end": json_record['reason_end'],
                      "shuffle": json_record['shuffle'],
                      "skipped": json_record['skipped'],
                      "offline": json_record['offline'],
                      "offline_timestamp": json_record['offline_timestamp'],
                      "incognito_mode": json_record['incognito_mode'],
                      "ip_addr": json_record['ip_addr'],
                    }  
                    ],
                    )
                # Commit the record
                conn.commit()

# %%
i = 0
for json_record in json_data:
    if i < 10:
        print(f"Artist : {json_record['master_metadata_album_artist_name']}")
        print(f"Track : {json_record['master_metadata_track_name']}")
        print()
        i += 1
    else:
        break

# %%
start_time = time.time()
extract_json_from_file(test_audio_file_path)
end_time = time.time()
print(f"elapsed minutes = {(end_time - start_time)/60}")
# Out:
# Artist : Ron Basejam Track : Get Closer
#
#
#
# Artist : Prof.Sakamoto Track : 8bit shower for SF Hyakkei (feat. Gainax)
#
#
#
# Artist : Prof.Sakamoto Track : We are here
#
#
#
# Artist : Prof.Sakamoto Track : Prologue
#
#
#
# Artist : Prof.Sakamoto Track : Field
#
#
#
# Artist : Prof.Sakamoto Track : Battle
#
#
#
# Artist : Prof.Sakamoto Track : Last Dungeon
#
#
#
# Artist : Prof.Sakamoto Track : Final Battle
#
#
#
# Artist : Prof.Sakamoto Track : Epilogue
#
#
#
# Artist : Prof.Sakamoto Track : 8bit shower for SF Hyakkei (feat. Gainax)
#
#
#
# Artist : Lars Behrenroth Track : Ice On The Sun
#
#
#
# Artist : Lars Behrenroth Track : Madness Last Night
#
#
#
# Artist : Lars Behrenroth Track : Keep On (Vocal Mix)
#
#
#
# Artist : Lars Behrenroth Track : Ice on the Sun - Version Remix
#
#
#
# Artist : Lars Behrenroth Track : Beach (Smith & Mudd remix)
#
#
#
# Artist : Lars Behrenroth Track : Kord
#
#
#
# Artist : Lars Behrenroth Track : Within Reason
#
#
#
# Artist : Lars Behrenroth Track : Within Reason
#
#
#
# Artist : Lars Behrenroth Track : Within Reason
#
#
#
# Artist : Lars Behrenroth Track : Within Reason
#
#
#
# Artist : Lars Behrenroth Track : Time
#
#
#
# Artist : Lars Behrenroth Track : Denots
#
#
#
# Artist : Lars Behrenroth Track : Subconscious Dark
#
#
#
# Artist : Lars Behrenroth Track : Kord
#
#
#
# Artist : Lars Behrenroth Track : Keep On (Vocal Mix)
#
#
#
# Artist : Lars Behrenroth Track : Time
#
#
#
# Artist : Lars Behrenroth Track : Denots
#
#
#
# Artist : Lars Behrenroth Track : Within Reason
#
#
#
# Artist : Lars Behrenroth Track : Madness Last Night
#
#
#
# Artist : Lars Behrenroth Track : Ice On The Sun
#
#
#
# Artist : Lars Behrenroth Track : Madness Last Night
#
#
#
# Artist : Lars Behrenroth Track : Keep On (Vocal Mix)
#
#
#
# Artist : Lars Behrenroth Track : Ice on the Sun - Version Remix
#
#
#
# Artist : Lars Behrenroth Track : Beach (Smith & Mudd remix)
#
#
#
# Artist : Lars Behrenroth Track : Kord
#
#
#
# Artist : Lars Behrenroth Track : Within Reason
#
#
#
# Artist : Lars Behrenroth Track : Time
#
#
#
# Artist : Lars Behrenroth Track : Denots
#
#
#
# Artist : Lars Behrenroth Track : Subconscious Dark
#
#
#
# Artist : Lars Behrenroth Track : Kord
#
#
#
# Artist : Lars Behrenroth Track : Keep On (Vocal Mix)
#
#
#
# Artist : Lars Behrenroth Track : Time
#
#
#
# Artist : Lars Behrenroth Track : Denots
#
#
#
# Artist : Lars Behrenroth Track : Within Reason
#
#
#
# Artist : Lars Behrenroth Track : Madness Last Night
#
#
#
# Artist : Lars Behrenroth Track : Ice On The Sun
#
#
#
# Artist : Lars Behrenroth Track : Madness Last Night
#
#
#
# Artist : Lars Behrenroth Track : Keep On (Vocal Mix)
#
#
#
# Artist : Pelican Track : The Creeper - Live
#
#
#
# Artist : Scott Walker Track : Brando
#
#
#
# Artist : Scott Walker Track : Brando
#
#
#
# Artist : sunn O))) Track : Sin-Nanna
#
#
#
# Artist : Tef Poe Track : Hilary
#
#
#
# Artist : Tef Poe Track : Prince
#
#
#
# Artist : Tef Poe Track : F.a.M.E.
#
#
#
# Artist : Assi El Hallani Track : Dalowna Mejana
#
#
#
# Artist : Fares Karam Track : Wailee Dalowna
#
#
#
# Artist : TOKiMONSTA Track : Darkest (Dim)
#
#
#
# Artist : TOKiMONSTA Track : Darkest (Dim)
#
#
#
# Artist : TOKiMONSTA Track : Darkest (Dim)
#
#
#
# Artist : Red Track : Darkest Part
#
#
#
# Artist : TOKiMONSTA Track : Darkest (Dim)
#
#
#
# Artist : Red Track : Darkest Part
#
#
#
# Artist : TOKiMONSTA Track : Darkest (Dim)
#
#
#
# Artist : TOKiMONSTA Track : Sweet Day
#
#
#
# Artist : Nosaj Thing Track : Aquarium
#
#
#
# Artist : TOKiMONSTA Track : Drive
#
#
#
# Artist : TOKiMONSTA Track : The Beginning
#
#
#
# Artist : TOKiMONSTA Track : Drive
#
#
#
# Artist : TOKiMONSTA Track : Steal My Attention
#
#
#
# Artist : TOKiMONSTA Track : Go With It
#
#
#
# Artist : Toro y Moi Track : Empty Nesters
#
#
#
# Artist : TOKiMONSTA Track : Steal My Attention
#
#
#
# Artist : TOKiMONSTA Track : Realla
#
#
#
# Artist : TOKiMONSTA Track : Dusty Stars
#
#
#
# Artist : TOKiMONSTA Track : Open Air
#
#
#
# Artist : TOKiMONSTA Track : Sakamoto's Spring
#
#
#
# Artist : TOKiMONSTA Track : The Beginning
#
#
#
# Artist : TOKiMONSTA Track : Drive
#
#
#
# Artist : TOKiMONSTA Track : The Beginning
#
#
#
# Artist : TOKiMONSTA Track : Sakamoto's Spring
#
#
#
# Artist : TOKiMONSTA Track : Realla
#
#
#
# Artist : TOKiMONSTA Track : Dusty Stars
#
#
#
# Artist : TOKiMONSTA Track : Steal My Attention
#
#
#
# Artist : TOKiMONSTA Track : Open Air
#
#
#
# Artist : TOKiMONSTA Track : Drive
#
#
#
# Artist : Toro y Moi Track : New Beat
#
#
#
# Artist : Unknown Mortal Orchestra Track : Multi-Love
#
#
#
# Artist : Nosaj Thing Track : Aquarium
#
#
#
# Artist : Beach Fossils Track : Sleep Apnea
#
#
#
# Artist : Toro y Moi Track : Lilly
#
#
#
# Artist : Ariel Pink Track : Baby
#
#
#
# Artist : Unknown Mortal Orchestra Track : Can’t Keep Checking My Phone
#
#
#
# Artist : Ariel Pink Track : Baby
#
#
#
# Artist : Unknown Mortal Orchestra Track : Can’t Keep Checking My Phone
#
#
#
# Artist : Ariel Pink Track : Baby
#
#
#
# Artist : Toro y Moi Track : Lilly
#
#
#
# Artist : Ariel Pink Track : Baby
#
#
#
# Artist : Unknown Mortal Orchestra Track : Can’t Keep Checking My Phone
#
#
#
# Artist : Blood Orange Track : You're Not Good Enough
#
#
#
# Artist : Beach House Track : Zebra
#
#
#
# Artist : Toro y Moi Track : So Many Details
#
#
#
# Artist : King Krule Track : The Noose of Jah City
#
#
#
# Artist : Toro y Moi Track : So Many Details
#
#
#
# Artist : King Krule Track : The Noose of Jah City
#
#
#
# Artist : DIIV Track : Dopamine
#
#
#
# Artist : Unknown Mortal Orchestra Track : Swim and Sleep (Like a Shark)
#
#
#
# Artist : Grizzly Bear Track : Ready, Able
#
#
#
# Artist : Toro y Moi Track : Minors
#
#
#
# Artist : Toro y Moi Track : Cola
#
#
#
# Artist : Flying Lotus Track : Never Catch Me
#
#
#
# Artist : Blood Orange Track : Augustine
#
#
#
# Artist : Ducktails Track : Killin The Vibe
#
#
#
# Artist : Ducktails Track : Killin The Vibe
#
#
#
# Artist : Toro y Moi Track : Run Baby Run
#
#
#
# Artist : Beach House Track : Space Song
#
#
#
# Artist : TOKiMONSTA Track : Giving Up (feat. Jonny Pierce) [Tom & Collins Remix]
#
#
#
# Artist : Blockhead Track : Insomniac Olympics
#
#
#
# Artist : Bibio Track : Petals
#
#
#
# Artist : Shigeto Track : Detroit Part 1
#
#
#
# Artist : Com Truise Track : Cyanide Sisters
#
#
#
# Artist : Thundercat Track : Show You The Way
#
#
#
# Artist : TOKiMONSTA Track : Soul to Seoul
#
#
#
# Artist : Bibio Track : Town & Country
#
#
#
# Artist : Flying Lotus Track : Zodiac Shit
#
#
#
# Artist : Baths Track : Aminals
#
#
#
# Artist : TOKiMONSTA Track : Dusty Stars
#
#
#
# Artist : Nosaj Thing Track : Aquarium
#
#
#
# Artist : Gold Panda Track : You
#
#
#
# Artist : Ta-ku Track : Make You Wanna
#
#
#
# Artist : TOKiMONSTA Track : Madness
#
#
#
# Artist : Thundercat Track : Them Changes (feat. Flying Lotus & Kamasi Washington)
#
#
#
# Artist : Com Truise Track : Alfa Beach
#
#
#
# Artist : Slow Magic Track : Closer
#
#
#
# Artist : TOKiMONSTA Track : Day Job
#
#
#
# Artist : Toro y Moi Track : New Beat
#
#
#
# Artist : Mndsgn Track : Hiking
#
#
#
# Artist : Hudson Mohawke Track : Scud Books
#
#
#
# Artist : Clams Casino Track : All Nite (feat. Vince Staples)
#
#
#
# Artist : TOKiMONSTA Track : Steal My Attention
#
#
#
# Artist : Flying Lotus Track : Do The Astral Plane
#
#
#
# Artist : Ta-ku Track : Love Again (feat. JMSN & Sango)
#
#
#
# Artist : Bibio Track : Bewley In Grey
#
#
#
# Artist : Mount Kimbie Track : Made To Stray
#
#
#
# Artist : TOKiMONSTA Track : Smoke & Mirrors
#
#
#
# Artist : Lorn Track : Anvil
#
#
#
# Artist : Rustie Track : Attak
#
#
#
# Artist : Prefuse 73 Track : Perverted Undertone
#
#
#
# Artist : TOKiMONSTA Track : Lucid Waking
#
#
#
# Artist : Giraffage Track : Bring Me Your Love (feat. THEA)
#
#
#
# Artist : Com Truise Track : Subsonic
#
#
#
# Artist : Evil Needle Track : Sunday Morning
#
#
#
# Artist : TOKiMONSTA Track : Drive
#
#
#
# Artist : Shlohmo Track : Apathy
#
#
#
# Artist : Toro y Moi Track : Buffalo
#
#
#
# Artist : Gavin Turek Track : On The Line
#
#
#
# Artist : TOKiMONSTA Track : Put It Down (feat. Anderson .Paak & KRANE)
#
#
#
# Artist : xxyyxx Track : About You
#
#
#
# Artist : Giraffage Track : Be With You
#
#
#
# Artist : Slow Magic Track : Girls
#
#
#
# Artist : TOKiMONSTA Track : Little Pleasures
#
#
#
# Artist : Chrome Sparks Track : Marijuana
#
#
#
# Artist : Shlohmo Track : Places
#
#
#
# Artist : Toro y Moi Track : Blessa
#
#
#
# Artist : The Gaslamp Killer Track : Nissim
#
#
#
# Artist : Devonwho Track : Lo
#
#
#
# Artist : TOKiMONSTA Track : Bright Shadows
#
#
#
# Artist : xxyyxx Track : Fields
#
#
#
# Artist : Ryan Hemsworth Track : Snow In Newark (feat. Dawn Golden)
#
#
#
# Artist : Evil Needle Track : Jazzolude - 1
#
#
#
# Artist : TOKiMONSTA Track : Waiting for the Break of Dawn
#
#
#
# Artist : Thundercat Track : Heartbreaks + Setbacks
#
#
#
# Artist : Flying Lotus Track : Massage Situation
#
#
#
# Artist : Ta-ku Track : Down For You (feat. Alina Baraz)
#
#
#
# Artist : TOKiMONSTA Track : Death by Disco
#
#
#
# Artist : Bibio Track : The Way You Talk
#
#
#
# Artist : Gavin Turek Track : The Distance
#
#
#
# Artist : Devonwho Track : Trio
#
#
#
# Artist : TOKiMONSTA Track : Wound Up (feat. a l l i e)
#
#
#
# Artist : Shlohmo Track : Wen Uuu
#
#
#
# Artist : Gold Panda Track : Metal Bird
#
#
#
# Artist : Toro y Moi Track : So Many Details
#
#
#
# Artist : TOKiMONSTA Track : Spilling Autumn
#
#
#
# Artist : Ta-ku Track : Meet In The Middle
#
#
#
# Artist : Mount Kimbie Track : Carbonated
#
#
#
# Artist : Flying Lotus Track : Camel
#
#
#
# Artist : Clams Casino Track : Be Somebody (feat. A$AP Rocky & Lil B)
#
#
#
# Artist : TOKiMONSTA Track : Sweet Williams
#
#
#
# Artist : xxyyxx Track : Breeze
#
#
#
# Artist : Nosaj Thing Track : Cold Stares (feat. Chance The Rapper & Maceo Haymes)
#
#
#
# Artist : Bibio Track : Night Falls
#
#
#
# Artist : TOKiMONSTA Track : Sweet Day
#
#
#
# Artist : Thundercat Track : Them Changes (feat. Flying Lotus & Kamasi Washington)
#
#
#
# Artist : Flying Lotus Track : Never Catch Me
#
#
#
# Artist : Giraffage Track : Feels
#
#
#
# Artist : TOKiMONSTA Track : Open Air
#
#
#
# Artist : Mndsgn Track : Abeja
#
#
#
# Artist : Shlohmo Track : Apathy
#
#
#
# Artist : Elaquent Track : Bucket List
#
#
#
# Artist : TOKiMONSTA Track : Look-a-Like
#
#
#
# Artist : Slow Magic Track : Closer
#
#
#
# Artist : xxyyxx Track : About You
#
#
#
# Artist : Giraffage Track : Bring Me Your Love (feat. THEA)
#
#
#
# Artist : TOKiMONSTA Track : Put It Down (feat. Anderson .Paak & KRANE)
#
#
#
# Artist : Toro y Moi Track : Harm In Change
#
#
#
# Artist : Chrome Sparks Track : Marijuana
#
#
#
# Artist : Hudson Mohawke Track : Play N Go
#
#
#
# Artist : TOKiMONSTA Track : Stigmatizing Sex
#
#
#
# Artist : Bibio Track : Lakeside
#
#
#
# Artist : Toro y Moi Track : Rose Quartz
#
#
#
# Artist : Gavin Turek Track : On The Line
#
#
#
# Artist : TOKiMONSTA Track : Green
#
#
#
# Artist : Giraffage Track : Be With You
#
#
#
# Artist : xxyyxx Track : Good Enough
#
#
#
# Artist : Slow Magic Track : Corvette Cassette
#
#
#
# Artist : TOKiMONSTA Track : Giving Up (feat. Jonny Pierce) [Tom & Collins Remix]
#
#
#
# Artist : Hiatus Kaiyote Track : Borderline with My Atoms
#
#
#
# Artist : Hiatus Kaiyote Track : Borderline with My Atoms
#
#
#
# Artist : Hiatus Kaiyote Track : Borderline with My Atoms
#
#
#
# Artist : The Internet Track : Special Affair
#
#
#
# Artist : Anderson .Paak Track : Put Me Thru
#
#
#
# Artist : José James Track : They Can’t Take That Away From Me
#
#
#
# Artist : Hiatus Kaiyote Track : Mobius Streak
#
#
#
# Artist : Little Dragon Track : Twice
#
#
#
# Artist : The Internet Track : Under Control
#
#
#
# Artist : SZA Track : Drew Barrymore
#
#
#
# Artist : Hiatus Kaiyote Track : Nakamarra (Rox N Stix Desert Mix)
#
#
#
# Artist : Mayer Hawthorne Track : The Walk
#
#
#
# Artist : Lianne La Havas Track : Unstoppable - FKJ Remix
#
#
#
# Artist : Erykah Badu Track : Phone Down
#
#
#
# Artist : Hiatus Kaiyote Track : Lace Skull
#
#
#
# Artist : SZA Track : Babylon (feat. Kendrick Lamar)
#
#
#
# Artist : Anderson .Paak Track : Heart Don't Stand a Chance
#
#
#
# Artist : Hiatus Kaiyote Track : The Lung
#
#
#
# Artist : Lianne La Havas Track : Green & Gold
#
#
#
# Artist : The Internet Track : Just Sayin/I Tried
#
#
#
# Artist : SZA Track : Sweet November
#
#
#
# Artist : NxWorries Track : What More Can I Say
#
#
#
# Artist : Hiatus Kaiyote Track : Breathing Underwater
#
#
#
# Artist : D'Angelo Track : Brown Sugar
#
#
#
# Artist : The Internet Track : Go with It (feat. VIC MENSA)
#
#
#
# Artist : Little Dragon Track : Constant Surprises
#
#
#
# Artist : Flying Lotus Track : Massage Situation
#
#
#
# Artist : Anderson .Paak Track : Am I Wrong (feat. ScHoolboy Q)
#
#
#
# Artist : Hiatus Kaiyote Track : Ocelot
#
#
#
# Artist : Esperanza Spalding Track : I Know You Know
#
#
#
# Artist : D'Angelo Track : Betray My Heart
#
#
#
# Artist : Erykah Badu Track : Didn't Cha Know
#
#
#
# Artist : Flying Lotus Track : Zodiac Shit
#
#
#
# Artist : Phony Ppl Track : Why iii Love The Moon.
#
#
#
# Artist : Hiatus Kaiyote Track : Boom Child
#
#
#
# Artist : Little Dragon Track : Ritual Union
#
#
#
# Artist : D'Angelo Track : Lady
#
#
#
# Artist : Jordan Rakei Track : The Light
#
#
#
# Artist : BADBADNOTGOOD Track : Confessions (feat. Leland Whitty)
#
#
#
# Artist : Hiatus Kaiyote Track : Atari
#
#
#
# Artist : SZA Track : Childs Play (feat. Chance the Rapper)
#
#
#
# Artist : Anderson .Paak Track : Parking Lot
#
#
#
# Artist : Vulfpeck Track : Animal Spirits
#
#
#
# Artist : Flying Lotus Track : Do The Astral Plane
#
#
#
# Artist : Thundercat Track : Show You The Way
#
#
#
# Artist : Hiatus Kaiyote Track : Prince Minikid
#
#
#
# Artist : Erykah Badu Track : On & On
#
#
#
# Artist : The Internet Track : For the World (feat. James Fauntleroy)
#
#
#
# Artist : SZA Track : Warm Winds (feat. Isaiah Rashad)
#
#
#
# Artist : Little Dragon Track : Shuffle A Dream
#
#
#
# Artist : Moses Sumney Track : Everlasting Sigh
#
#
#
# Artist : Hiatus Kaiyote Track : By Fire
#
#
#
# Artist : The Internet Track : Palace/Curse (feat. Tyler, The Creator & Steve Lacy)
#
#
#
# Artist : Emily King Track : Distance
#
#
#
# Artist : Vulfpeck Track : Conscious Club
#
#
#
# Artist : D'Angelo Track : Another Life
#
#
#
# Artist : Flying Lotus Track : Never Catch Me
#
#
#
# Artist : Hiatus Kaiyote Track : Jekyll
#
#
#
# Artist : NxWorries Track : Suede
#
#
#
# Artist : The Internet Track : Girl (feat. KAYTRANADA)
#
#
#
# Artist : Eric Lau Track : Its Rainy
#
#
#
# Artist : Takuya Kuroda Track : Everybody Loves The Sunshine
#
#
#
# Artist : Hiatus Kaiyote Track : The Lung
#
#
#
# Artist : Anderson .Paak Track : Your Prime
#
#
#
# Artist : Mayer Hawthorne Track : Just Ain't Gonna Work Out
#
#
#
# Artist : Slum Village Track : Fall In Love
#
#
#
# Artist : Vulfpeck Track : Back Pocket
#
#
#
# Artist : Hiatus Kaiyote Track : Malika
#
#
#
# Artist : The Internet Track : Get Away
#
#
#
# Artist : Christian Scott aTunde Adjuah Track : Isadora
#
#
#
# Artist : Hiatus Kaiyote Track : Creations Part Two
#
#
#
# Artist : Vulfpeck Track : Funky Duck
#
#
#
# Artist : Nick Hakim Track : I Don't Know
#
#
#
# Artist : Erykah Badu Track : Window Seat
#
#
#
# Artist : Anderson .Paak Track : Silicon Valley
#
#
#
# Artist : The Internet Track : Gabby (feat. Janelle Monáe)
#
#
#
# Artist : Hiatus Kaiyote Track : Laputa (Taylor McFerrin Remix feat. Anderson .Paak)
#
#
#
# Artist : D'Angelo Track : Brown Sugar
#
#
#
# Artist : Jordan Rakei Track : Alright
#
#
#
# Artist : Laura Mvula Track : Ready or Not - NK-OK x Blue Lab Beats Remix
#
#
#
# Artist : Flying Lotus Track : Massage Situation
#
#
#
# Artist : Hiatus Kaiyote Track : Rainbow Rhodes
#
#
#
# Artist : D'Angelo Track : Untitled (How Does It Feel)
#
#
#
# Artist : Thundercat Track : Them Changes (feat. Flying Lotus & Kamasi Washington)
#
#
#
# Artist : Phony Ppl Track : Why iii Love The Moon.
#
#
#
# Artist : The Internet Track : Just Sayin/I Tried
#
#
#
# Artist : Hiatus Kaiyote Track : Leap Frog
#
#
#
# Artist : NxWorries Track : Best One
#
#
#
# Artist : Little Dragon Track : High
#
#
#
# Artist : Erykah Badu Track : Didn't Cha Know
#
#
#
# Artist : Lianne La Havas Track : Say a Little Prayer - Live
#
#
#
# Artist : Anderson .Paak Track : Miss Right
#
#
#
# Artist : The Internet Track : Palace/Curse (feat. Tyler, The Creator & Steve Lacy)
#
#
#
# Artist : Erykah Badu Track : On & On
#
#
#
# Artist : D'Angelo Track : Another Life
#
#
#
# Artist : Hiatus Kaiyote Track : Fingerprints
#
#
#
# Artist : Moses Sumney Track : Plastic (Mid-City Island Version)
#
#
#
# Artist : Little Dragon Track : Ritual Union
#
#
#
# Artist : Lianne La Havas Track : Green & Gold
#
#
#
# Artist : Anderson .Paak Track : Already (feat. SiR)
#
#
#
# Artist : The Internet Track : Girl (feat. KAYTRANADA)
#
#
#
# Artist : Hiatus Kaiyote Track : Borderline with My Atoms
#
#
#
# Artist : Flying Lotus Track : Never Catch Me
#
#
#
# Artist : Flying Lotus Track : Never Catch Me
#
#
#
# Artist : Thundercat Track : Show You The Way
#
#
#
# Artist : Baths Track : Aminals
#
#
#
# Artist : Bibio Track : Town & Country
#
#
#
# Artist : J Dilla Track : Dillatronic 01
#
#
#
# Artist : Aphex Twin Track : Avril 14th
#
#
#
# Artist : Flying Lotus Track : Putty Boy Strut
#
#
#
# Artist : Nosaj Thing Track : Aquarium
#
#
#
# Artist : Com Truise Track : Cyanide Sisters
#
#
#
# Artist : Shlohmo Track : Places
#
#
#
# Artist : Com Truise Track : Cyanide Sisters
#
#
#
# Artist : Shlohmo Track : Places
#
#
#
# Artist : Death Grips Track : Get Got
#
#
#
# Artist : Moses Sumney Track : Lonely World
#
#
#
# Artist : Baio Track : Sister Of Pearl
#
#
#
# Artist : Damien Jurado Track : Kola
#
#
#
# Artist : Jamila Woods Track : Blk Girl Soldier
#
#
#
# Artist : Run The Jewels Track : Legend Has It
#
#
#
# Artist : Sorority Noise Track : Blonde Hair, Black Lungs
#
#
#
# Artist : Kevin Morby Track : Beautiful Strangers
#
#
#
# Artist : Ezra Furman Track : Lousy Connection
#
#
#
# Artist : Death Grips Track : Get Got
#
#
#
# Artist : Four Tet Track : Locked
#
#
#
# Artist : Death Grips Track : Get Got
#
#
#
# Artist : Shlohmo Track : Places
#
#
#
# Artist : Death Grips Track : Get Got
#
#
#
# Artist : Four Tet Track : Locked
#
#
#
# Artist : Flying Lotus Track : ...And The World Laughs With You
#
#
#
# Artist : Four Tet Track : Locked
#
#
#
# Artist : Flying Lotus Track : ...And The World Laughs With You
#
#
#
# Artist : Boards of Canada Track : Dayvan Cowboy
#
#
#
# Artist : Aphex Twin Track : Windowlicker - EP Version
#
#
#
# Artist : Boards of Canada Track : Dayvan Cowboy
#
#
#
# Artist : Aphex Twin Track : Windowlicker - EP Version
#
#
#
# Artist : Flying Lotus Track : Turkey Dog Coma
#
#
#
# Artist : MF DOOM Track : Deep Fried Frenz
#
#
#
# Artist : Prefuse 73 Track : Perverted Undertone
#
#
#
# Artist : MF DOOM Track : Deep Fried Frenz
#
#
#
# Artist : Prefuse 73 Track : Perverted Undertone
#
#
#
# Artist : Bibio Track : Petals
#
#
#
# Artist : Flying Lotus Track : Do The Astral Plane
#
#
#
# Artist : Death Grips Track : Guillotine
#
#
#
# Artist : Flying Lotus Track : Do The Astral Plane
#
#
#
# Artist : Bibio Track : Petals
#
#
#
# Artist : Prefuse 73 Track : Perverted Undertone
#
#
#
# Artist : Bibio Track : Petals
#
#
#
# Artist : Death Grips Track : Guillotine
#
#
#
# Artist : Madvillain Track : Figaro
#
#
#
# Artist : J Dilla Track : Dillatronic 09
#
#
#
# Artist : Flying Lotus Track : Stonecutters
#
#
#
# Artist : Shlohmo Track : Wen Uuu
#
#
#
# Artist : Flying Lotus Track : Stonecutters
#
#
#
# Artist : Shlohmo Track : Wen Uuu
#
#
#
# Artist : Toro y Moi Track : New Beat
#
#
#
# Artist : Madvillain Track : Accordion
#
#
#
# Artist : Flying Lotus Track : Heave(n)
#
#
#
# Artist : Mndsgn Track : Camelblues
#
#
#
# Artist : TOKiMONSTA Track : Go With It
#
#
#
# Artist : Aphex Twin Track : aisatsana [102]
#
#
#
# Artist : Flying Lotus Track : Melt!
#
#
#
# Artist : Boards of Canada Track : Reach For The Dead
#
#
#
# Artist : MF DOOM Track : Vomitspit
#
#
#
# Artist : Flying Lotus Track : Satelllliiiiiiiteee
#
#
#
# Artist : Aphex Twin Track : I
#
#
#
# Artist : Toro y Moi Track : Rose Quartz
#
#
#
# Artist : Shabazz Palaces Track : Swerve... the reeping of all that is worthwhile (Noir not withstanding)
#
#
#
# Artist : Flying Lotus Track : Coronus, the Terminator
#
#
#
# Artist : Bibio Track : Bewley In Grey
#
#
#
# Artist : MF DOOM Track : Beef Rap
#
#
#
# Artist : J Dilla Track : 764
#
#
#
# Artist : Toro y Moi Track : So Many Details
#
#
#
# Artist : Flying Lotus Track : Tea Leaf Dancers (Moodymann Edit) - Mixed
#
#
#
# Artist : Thundercat Track : Them Changes (feat. Flying Lotus & Kamasi Washington)
#
#
#
# Artist : BADBADNOTGOOD Track : Lavender (feat. Kaytranada)
#
#
#
# Artist : MF DOOM Track : One Beer
#
#
#
# Artist : Flying Lotus Track : Massage Situation
#
#
#
# Artist : Mount Kimbie Track : Made To Stray
#
#
#
# Artist : Clams Casino Track : Into the Fire (feat. Mikky Ekko)
#
#
#
# Artist : Mount Kimbie Track : Made To Stray
#
#
#
# Artist : Tacocat Track : Crimson Wave
#
#
#
# Artist : Tacocat Track : I Hate the Weekend
#
#
#
# Artist : Tacocat Track : Dana Katherine Scully
#
#
#
# Artist : Tacocat Track : The Internet
#
#
#
# Artist : Tacocat Track : I Love Seattle
#
#
#
# Artist : Tacocat Track : Men Explain Things to Me
#
#
#
# Artist : Tacocat Track : Bridge to Hawaii
#
#
#
# Artist : Tacocat Track : Talk
#
#
#
# Artist : Tacocat Track : You Can't Fire Me, I Quit
#
#
#
# Artist : Tacocat Track : FDP
#
#
#
# Artist : Sampha Track : Timmy's Prayer
#
#
#
# Artist : Sampha Track : Happens
#
#
#
# Artist : Solange Track : Don't Touch My Hair (feat. Sampha)
#
#
#
# Artist : SBTRKT Track : Temporary View
#
#
#
# Artist : Sampha Track : Reverse Faults
#
#
#
# Artist : Sampha Track : Blood on Me
#
#
#
# Artist : Sampha Track : Without
#
#
#
# Artist : Sampha Track : Blood on Me
#
#
#
# Artist : Sampha Track : Reverse Faults
#
#
#
# Artist : SBTRKT Track : Temporary View
#
#
#
# Artist : Solange Track : Don't Touch My Hair (feat. Sampha)
#
#
#
# Artist : SBTRKT Track : Temporary View
#
#
#
# Artist : Sampha Track : Reverse Faults
#
#
#
# Artist : Sampha Track : Blood on Me
#
#
#
# Artist : Sampha Track : Reverse Faults
#
#
#
# Artist : Sampha Track : Blood on Me
#
#
#
# Artist : Sampha Track : Reverse Faults
#
#
#
# Artist : Sampha Track : Blood on Me
#
#
#
# Artist : Sampha Track : Without
#
#
#
# Artist : SBTRKT Track : Sanctuary
#
#
#
# Artist : SBTRKT Track : Living Like I Do
#
#
#
# Artist : SBTRKT Track : TBD (feat. Sampha)
#
#
#
# Artist : SBTRKT Track : Hold On
#
#
#
# Artist : Jessie Ware Track : Valentine
#
#
#
# Artist : Short Stories Track : On the Way
#
#
#
# Artist : Sampha Track : (No One Knows Me) Like the Piano
#
#
#
# Artist : Sampha Track : Indecision
#
#
#
# Artist : Sampha Track : Incomplete Kisses
#
#
#
# Artist : Drake Track : Too Much
#
#
#
# Artist : Sampha Track : What Shouldn't I Be?
#
#
#
# Artist : Lil Silva Track : On Your Own
#
#
#
# Artist : SBTRKT Track : Something Goes Right
#
#
#
# Artist : SBTRKT Track : Evening Glow - Reprise
#
#
#
# Artist : SBTRKT Track : Wonder Where We Land
#
#
#
# Artist : Sampha Track : Beneath The Tree
#
#
#
# Artist : Lil Silva Track : Salient Sarah (feat. Sampha)
#
#
#
# Artist : Sampha Track : Can't Get Close
#
#
#
# Artist : Sampha Track : Timmy's Prayer
#
#
#
# Artist : Sampha Track : Happens
#
#
#
# Artist : Solange Track : Don't Touch My Hair (feat. Sampha)
#
#
#
# Artist : SBTRKT Track : Temporary View
#
#
#
# Artist : Sampha Track : Reverse Faults
#
#
#
# Artist : Sampha Track : Blood on Me
#
#
#
# Artist : Sampha Track : Without
#
#
#
# Artist : SBTRKT Track : Sanctuary
#
#
#
# Artist : SBTRKT Track : Living Like I Do
#
#
#
# Artist : SBTRKT Track : TBD (feat. Sampha)
#
#
#
# Artist : SBTRKT Track : Hold On
#
#
#
# Artist : SBTRKT Track : Hold On
#
#
#
# Artist : Sampha Track : Incomplete Kisses
#
#
#
# Artist : Drake Track : Too Much
#
#
#
# Artist : Sampha Track : Indecision
#
#
#
# Artist : Drake Track : Too Much
#
#
#
# Artist : Sampha Track : Incomplete Kisses
#
#
#
# Artist : Drake Track : Too Much
#
#
#
# Artist : Sampha Track : Incomplete Kisses
#
#
#
# Artist : Sampha Track : Incomplete Kisses
#
#
#
# Artist : Drake Track : Too Much
#
#
#
# Artist : Sampha Track : Indecision
#
#
#
# Artist : SBTRKT Track : Temporary View
#
#
#
# Artist : Sampha Track : Happens
#
#
#
# Artist : Jessie Ware Track : Valentine
#
#
#
# Artist : Shigeto Track : Detroit Part 1
#
#
#
# Artist : Shlohmo Track : Wen Uuu
#
#
#
# Artist : TOKiMONSTA Track : Darkest (Dim)
#
#
#
# Artist : Ducktails Track : Killin The Vibe
#
#
#
# Artist : Gold Panda Track : Metal Bird
#
#
#
# Artist : Floating Points Track : Sais
#
#
#
# Artist : Gold Panda Track : Metal Bird
#
#
#
# Artist : Ducktails Track : Killin The Vibe
#
#
#
# Artist : Gold Panda Track : Metal Bird
#
#
#
# Artist : Floating Points Track : Sais
#
#
#
# Artist : Shlohmo Track : Wen Uuu
#
#
#
# Artist : Toro y Moi Track : New Beat
#
#
#
# Artist : Aphex Twin Track : Windowlicker - EP Version
#
#
#
# Artist : Rustie Track : Attak
#
#
#
# Artist : xxyyxx Track : About You
#
#
#
# Artist : xxyyxx Track : About You
#
#
#
# Artist : Mndsgn Track : Laps
#
#
#
# Artist : Flying Lotus Track : Never Catch Me
#
#
#
# Artist : BADBADNOTGOOD Track : Lavender (feat. Kaytranada)
#
#
#
# Artist : BADBADNOTGOOD Track : Lavender (feat. Kaytranada)
#
#
#
# Artist : Unknown Mortal Orchestra Track : Can’t Keep Checking My Phone
#
#
#
# Artist : Little Dragon Track : Ritual Union
#
#
#
# Artist : Little Dragon Track : Ritual Union
#
#
#
# Artist : Dirty Projectors Track : Maybe That Was It
#
#
#
# Artist : Thundercat Track : Heartbreaks + Setbacks
#
#
#
# Artist : Thundercat Track : Rabbot Ho
#
#
#
# Artist : Thundercat Track : Where I'm Going
#
#
#
# Artist : Thundercat Track : Them Changes
#
#
#
# Artist : Thundercat Track : Show You the Way
#
#
#
# Artist : Thundercat Track : Lava Lamp
#
#
#
# Artist : Thundercat Track : Lava Lamp
#
#
#
# Artist : Thundercat Track : Drink Dat
#
#
#
# Artist : Thundercat Track : Walk on By
#
#
#
# Artist : Thundercat Track : Jameel's Space Ride
#
#
#
# Artist : Thundercat Track : Day & Night
#
#
#
# Artist : Thundercat Track : 3AM
#
#
#
# Artist : Thundercat Track : Blackkk
#
#
#
# Artist : Thundercat Track : I am Crazy
#
#
#
# Artist : Thundercat Track : A Fan's Mail (Tron Song Suite II)
#
#
#
# Artist : Thundercat Track : DUI
#
#
#
# Artist : Thundercat Track : Captain Stupido
#
#
#
# Artist : Thundercat Track : Bus In These Streets
#
#
#
# Artist : Thundercat Track : Jethro
#
#
#
# Artist : Thundercat Track : Bus In These Streets
#
#
#
# Artist : Thundercat Track : Jethro
#
#
#
# Artist : Thundercat Track : Uh Uh
#
#
#
# Artist : Thundercat Track : Drunk
#
#
#
# Artist : Thundercat Track : Inferno
#
#
#
# Artist : Thundercat Track : The Turn Down
#
#
#
# Artist : Thundercat Track : Tokyo
#
#
#
# Artist : Thundercat Track : Friend Zone
#
#
#
# Artist : Thundercat Track : Rabbot Ho
#
#
#
# Artist : Kilo Kish Track : Self Importance
#
#
#
# Artist : Kilo Kish Track : Fulfillment?
#
#
#
# Artist : Kilo Kish Track : Hello, Lakisha
#
#
#
# Artist : Kilo Kish Track : Distractions I: The Opposite Sex
#
#
#
# Artist : Kilo Kish Track : Navy
#
#
#
# Artist : Kilo Kish Track : Locket - RRReymundo Remix
#
#
#
# Artist : Kilo Kish Track : Locket
#
#
#
# Artist : Kilo Kish Track : Frustrations + Solutions
#
#
#
# Artist : Kilo Kish Track : Age + Self Esteem: A Funhouse Mirror
#
#
#
# Artist : Kilo Kish Track : Curious
#
#
#
# Artist : Kilo Kish Track : Distractions II: The Dilemma of Cool
#
#
#
# Artist : Kilo Kish Track : Taking Responsibility
#
#
#
# Artist : Kilo Kish Track : Existential Crisis Hour!
#
#
#
# Artist : Kilo Kish Track : Begin Route
#
#
#
# Artist : Kilo Kish Track : Locket - RRReymundo Remix
#
#
#
# Artist : Kilo Kish Track : Wax - RRReymundo Remix
#
#
#
# Artist : Kilo Kish Track : Thoughts on Love and Work
#
#
#
# Artist : Kilo Kish Track : Curious (Le Flex Remix) [Bonus Track]
#
#
#
# Artist : Kilo Kish Track : Relief! (My Answers So Far)
#
#
#
# Artist : Kilo Kish Track : Curious - RRReymundo Remix
#
#
#
# Artist : Kilo Kish Track : Begin Rout (Intro) [RRReymundo Remix]
#
#
#
# Artist : Kilo Kish Track : Hello, Lakisha
#
#
#
# Artist : Kilo Kish Track : Thoughts on Love and Work - RRReymundo Remix
#
#
#
# Artist : Kilo Kish Track : Distractions I: The Opposite Sex
#
#
#
# Artist : Kilo Kish Track : On the Way - RRReymundo Remix
#
#
#
# Artist : Kilo Kish Track : Destination
#
#
#
# Artist : Kilo Kish Track : Navy - MeLo-X Remix
#
#
#
# Artist : Kilo Kish Track : Age + Self Esteem: A Funhouse Mirror
#
#
#
# Artist : Kilo Kish Track : Curious
#
#
#
# Artist : Kilo Kish Track : Wax - RRReymundo Remix
#
#
#
# Artist : Kilo Kish Track : Thank You!
#
#
#
# Artist : Kilo Kish Track : Navy
#
#
#
# Artist : Kilo Kish Track : On the Way - RRReymundo Remix
#
#
#
# Artist : Kilo Kish Track : Wax
#
#
#
# Artist : Kilo Kish Track : Destination
#
#
#
# Artist : Kilo Kish Track : Curious - RRReymundo Remix
#
#
#
# Artist : Kilo Kish Track : Life: The Cruel Interlude (On God)
#
#
#
# Artist : Kilo Kish Track : On the Mend
#
#
#
# Artist : Kilo Kish Track : The Fears of a Dilettante
#
#
#
# Artist : Kilo Kish Track : Curious
#
#
#
# Artist : Kilo Kish Track : Self Importance
#
#
#
# Artist : Kilo Kish Track : Poem A
#
#
#
# Artist : Kilo Kish Track : Frustrations + Solutions
#
#
#
# Artist : Kilo Kish Track : Begin Route
#
#
#
# Artist : Kilo Kish Track : On the Way
#
#
#
# Artist : Kilo Kish Track : Locket
#
#
#
# Artist : Kilo Kish Track : Thoughts on Love and Work
#
#
#
# Artist : Kilo Kish Track : Outpatient Mentality
#
#
#
# Artist : Kilo Kish Track : Wrong
#
#
#
# Artist : Kilo Kish Track : Fulfillment?
#
#
#
# Artist : Kilo Kish Track : Wrong
#
#
#
# Artist : Kilo Kish Track : Begin Route (Intro) [RRReymundo Remix]
#
#
#
# Artist : Kilo Kish Track : Collected Views from Dinner
#
#
#
# Artist : Kilo Kish Track : Wax
#
#
#
# Artist : Kilo Kish Track : Thoughts on Love and Work - RRReymundo Remix
#
#
#
# Artist : Kilo Kish Track : Wrong - RRReymundo Remix
#
#
#
# Artist : Kilo Kish Track : On the Way
#
#
#
# Artist : Kilo Kish Track : Humans + Ants in Proportion (Unfinished)
#
#
#
# Artist : Kilo Kish Track : Intermission
#
#
#
# Artist : Kilo Kish Track : Locket - RRReymundo Remix
#
#
#
# Artist : Kilo Kish Track : Obsessing
#
#
#
# Artist : Kilo Kish Track : Wrong - RRReymundo Remix
#
#
#
# Artist : Kilo Kish Track : Locket
#
#
#
# Artist : Kilo Kish Track : Self Importance
#
#
#
# Artist : Kilo Kish Track : Locket
#
#
#
# Artist : Kilo Kish Track : Locket
#
#
#
# Artist : Kilo Kish Track : Self Importance
#
#
#
# Artist : Kilo Kish Track : Hello, Lakisha
#
#
#
# Artist : Kilo Kish Track : Locket - RRReymundo Remix
#
#
#
# Artist : Kilo Kish Track : Locket
#
#
#
# Artist : Kilo Kish Track : Locket
#
#
#
# Artist : Kilo Kish Track : Self Importance
#
#
#
# Artist : Kilo Kish Track : Hello, Lakisha
#
#
#
# Artist : Kilo Kish Track : Locket - RRReymundo Remix
#
#
#
# Artist : Muhsinah Track : GORGEOUS
#
#
#
# Artist : SZA Track : Green Mile
#
#
#
# Artist : SZA Track : Green Mile
#
#
#
# Artist : FKA twigs Track : Pendulum
#
#
#
# Artist : SZA Track : Green Mile
#
#
#
# Artist : FKA twigs Track : Pendulum
#
#
#
# Artist : Shy Girls Track : Synthesize Me
#
#
#
# Artist : SiR Track : He Deserves Your Love
#
#
#
# Artist : Tei Shi Track : How Far
#
#
#
# Artist : SiR Track : He Deserves Your Love
#
#
#
# Artist : Fred Everything Track : Friday feat. Vanessa Baker - Crazy P Remix
#
#
#
# Artist : Fred Everything Track : Friday feat. Vanessa Baker - Crazy P Remix
#
#
#
# Artist : Fred Everything Feat. Roy Davis Jr. Track : On My Own (Giom Mix)
#
#
#
# Artist : cates&dpL Track : Through The Weekend - Audio Soul Project Remix
#
#
#
# Artist : cates&dpL Track : Through The Weekend - Audio Soul Project Remix
#
#
#
# Artist : Fred Everything Track : Radio Everything
#
#
#
# Artist : Fred Everything Track : A Better World - Original Mix
#
#
#
# Artist : Fred Everything Track : Winter Blues
#
#
#
# Artist : Fred Everything Track : Lost Together
#
#
#
# Artist : Fred Everything Track : Believe (feat. Kathy Diamond) - Giom Remix
#
#
#
# Artist : Sot Track : Believe - New Mastersounds Mix
#
#
#
# Artist : Boddhi Satva Track : Mama Kosa (Radio Edit)
#
#
#
# Artist : Boddhi Satva Track : Mama Kosa (Atjazz Astro Dub)
#
#
#
# Artist : Boddhi Satva Track : Mama Kosa (Main Instrumental Mix)
#
#
#
# Artist : Boddhi Satva Track : Mama Kosa (Atjazz Astro Dub)
#
#
#
# Artist : Boddhi Satva Track : Mama Kosa (Main Instrumental Mix)
#
#
#
# Artist : Boddhi Satva Track : Mama Kosa (Atjazz Astro Dub)
#
#
#
# Artist : Boddhi Satva Track : Mama Kosa (Atjazz Astro Dub)
#
#
#
# Artist : Boddhi Satva Track : Mama Kosa (Main Instrumental Mix)
#
#
#
# Artist : Boddhi Satva Track : Mama Kosa (Atjazz Astro Dub)
#
#
#
# Artist : Boddhi Satva Track : Mama Kosa (Main Instrumental Mix)
#
#
#
# Artist : Boddhi Satva Track : Mama Kosa (Atjazz Astro Dub)
#
#
#
# Artist : Boddhi Satva Track : Mama Kosa (Main Instrumental Mix)
#
#
#
# Artist : Boddhi Satva Track : Mama Kosa (Atjazz Astro Dub)
#
#
#
# Artist : Boddhi Satva Track : Mama Kosa (Main Instrumental Mix)
#
#
#
# Artist : Boddhi Satva Track : Mama Kosa (Atjazz Astro Dub)
#
#
#
# Artist : Boddhi Satva Track : Mama Kosa (Main Instrumental Mix)
#
#
#
# Artist : Boddhi Satva Track : Mama Kosa (Atjazz Astro Dub)
#
#
#
# Artist : Boddhi Satva Track : Mama Kosa (Main Instrumental Mix)
#
#
#
# Artist : Boddhi Satva Track : Mama Kosa (Atjazz Astro Dub)
#
#
#
# Artist : Boddhi Satva Track : Mama Kosa (Main Instrumental Mix)
#
#
#
# Artist : Boddhi Satva Track : Mama Kosa (Dubstrumental Mix)
#
#
#
# Artist : Boddhi Satva Track : Mama Kosa (Mr. de Shada Remix)
#
#
#
# Artist : Boddhi Satva Track : Mama Kosa (Main Mix)
#
#
#
# Artist : Boddhi Satva Track : Mama Kosa (Dub Mix)
#
#
#
# Artist : Thundercat Track : Walk on By
#
#
#
# Artist : Thundercat Track : Fleer Ultra
#
#
#
# Artist : Thundercat Track : Inferno
#
#
#
# Artist : Thundercat Track : Seven
#
#
#
# Artist : Boddhi Satva Track : Mama Kosa (Dub Mix)
#
#
#
# Artist : Thundercat Track : Drink Dat
#
#
#
# Artist : Thundercat Track : Them Changes
#
#
#
# Artist : Thundercat Track : Them Changes
#
#
#
# Artist : Thundercat Track : Tron Song
#
#
#
# Artist : Thundercat Track : Them Changes
#
#
#
# Artist : Thundercat Track : Tron Song
#
#
#
# Artist : Thundercat Track : Seasons
#
#
#
# Artist : Thundercat Track : Is It Love?
#
#
#
# Artist : Thundercat Track : Is It Love?
#
#
#
# Artist : Thundercat Track : Daylight
#
#
#
# Artist : Thundercat Track : Walkin'
#
#
#
# Artist : Thundercat Track : Goldenboy
#
#
#
# Artist : Thundercat Track : Tenfold
#
#
#
# Artist : Thundercat Track : Lotus and the Jondy
#
#
#
# Artist : Thundercat Track : Friend Zone
#
#
#
# Artist : Thundercat Track : Friend Zone
#
#
#
# Artist : Thundercat Track : Fleer Ultra
#
#
#
# Artist : Thundercat Track : Friend Zone
#
#
#
# Artist : Thundercat Track : Lotus and the Jondy
#
#
#
# Artist : Thundercat Track : Friend Zone
#
#
#
# Artist : Thundercat Track : Fleer Ultra
#
#
#
# Artist : Thundercat Track : We'll Die
#
#
#
# Artist : Thundercat Track : Show You The Way
#
#
#
# Artist : Thundercat Track : Them Changes (feat. Flying Lotus & Kamasi Washington)
#
#
#
# Artist : Thundercat Track : For Love I Come
#
#
#
# Artist : Thundercat Track : A Message for Austin / Praise the Lord / Enter the Void
#
#
#
# Artist : Thundercat Track : Special Stage
#
#
#
# Artist : Thundercat Track : Boat Cruise
#
#
#
# Artist : Thundercat Track : Mystery Machine (The Golden Age of Apocalypse)
#
#
#
# Artist : Thundercat Track : The Life Aquatic
#
#
#
# Artist : Thundercat Track : Return to the Journey
#
#
#
# Artist : Thundercat Track : Them Changes (feat. Flying Lotus & Kamasi Washington)
#
#
#
# Artist : Thundercat Track : Jamboree
#
#
#
# Artist : Thundercat Track : That Moment (feat. Flying Lotus)
#
#
#
# Artist : Thundercat Track : HooooooO
#
#
#
# Artist : Thundercat Track : Lone Wolf and Cub (feat. Herbie Hancock, Flying Lotus, Miguel Atwood-Ferguson & Mono/poly)
#
#
#
# Artist : Thundercat Track : Where The Giants Roam / Field of the Nephilim (feat. Mono/poly)
#
#
#
# Artist : Thundercat Track : Evangelion
#
#
#
# Artist : Thundercat Track : Song for the Dead (feat. Miguel Atwood-Ferguson & Mono/poly)
#
#
#
# Artist : Thundercat Track : Seven
#
#
#
# Artist : Thundercat Track : Without You
#
#
#
# Artist : Thundercat Track : Oh Sheit It's X
#
#
#
# Artist : Thundercat Track : Bus In These Streets
#
#
#
# Artist : Thundercat Track : Hard Times
#
#
#
# Artist : Thundercat Track : It Really Doesn't Matter to You
#
#
#
# Artist : Thundercat Track : Heartbreaks + Setbacks
#
#
#
# Artist : Thundercat Track : Show You the Way
#
#
#
# Artist : Thundercat Track : DUI
#
#
#
# Artist : Thundercat Track : 3AM
#
#
#
# Artist : Thundercat Track : Lava Lamp
#
#
#
# Artist : Thundercat Track : Lava Lamp
#
#
#
# Artist : Thundercat Track : A Fan's Mail (Tron Song Suite II)
#
#
#
# Artist : Thundercat Track : Day & Night
#
#
#
# Artist : Thundercat Track : Drunk
#
#
#
# Artist : Thundercat Track : Uh Uh
#
#
#
# Artist : Thundercat Track : Jethro
#
#
#
# Artist : Thundercat Track : Captain Stupido
#
#
#
# Artist : Thundercat Track : Walk on By
#
#
#
# Artist : Thundercat Track : I am Crazy
#
#
#
# Artist : Thundercat Track : Where I'm Going
#
#
#
# Artist : Thundercat Track : The Turn Down
#
#
#
# Artist : Thundercat Track : Uh Uh
#
#
#
# Artist : Thundercat Track : Rabbot Ho
#
#
#
# Artist : Thundercat Track : Bus In These Streets
#
#
#
# Artist : Thundercat Track : Friend Zone
#
#
#
# Artist : Thundercat Track : A Fan's Mail (Tron Song Suite II)
#
#
#
# Artist : Thundercat Track : Jameel's Space Ride
#
#
#
# Artist : TOKiMONSTA Track : Dusty Stars
#
#
#
# Artist : Toro y Moi Track : New Beat
#
#
#
# Artist : Aphex Twin Track : aisatsana [102]
#
#
#
# Artist : Flying Lotus Track : Camel
#
#
#
# Artist : Com Truise Track : Cyanide Sisters
#
#
#
# Artist : Bibio Track : Dye the Water Green
#
#
#
# Artist : NxWorries Track : Best One
#
#
#
# Artist : Little Dragon Track : Ritual Union
#
#
#
# Artist : NxWorries Track : Best One
#
#
#
# Artist : NxWorries Track : Scared Money
#
#
#
# Artist : NxWorries Track : Livvin
#
#
#
# Artist : NxWorries Track : Intro
#
#
#
# Artist : NxWorries Track : Jodi
#
#
#
# Artist : NxWorries Track : Kutless
#
#
#
# Artist : NxWorries Track : Can’t Stop
#
#
#
# Artist : NxWorries Track : H.A.N.
#
#
#
# Artist : NxWorries Track : Wngs
#
#
#
# Artist : NxWorries Track : Sidepiece
#
#
#
# Artist : NxWorries Track : Another Time
#
#
#
# Artist : NxWorries Track : Khadijah
#
#
#
# Artist : NxWorries Track : What More Can I Say
#
#
#
# Artist : NxWorries Track : Suede
#
#
#
# Artist : NxWorries Track : Get Bigger / Do U Luv
#
#
#
# Artist : NxWorries Track : Link Up
#
#
#
# Artist : NxWorries Track : Lyk Dis
#
#
#
# Artist : Leroy & The Galahads Track : Fidget
#
#
#
# Artist : Leroy & The Galahads Track : Fidget
#
#
#
# Artist : The Classics Track : Till Then
#
#
#
# Artist : The Flamingos Track : I Only Have Eyes For You
#
#
#
# Artist : The Diamonds Track : Little Darlin'
#
#
#
# Artist : The Skyliners Track : Since I Don't Have You
#
#
#
# Artist : NxWorries Track : Best One
#
#
#
# Artist : Little Dragon Track : Ritual Union
#
#
#
# Artist : Gold Panda Track : You
#
#
#
# Artist : Prefuse 73 Track : Perverted Undertone
#
#
#
# Artist : How To Dress Well Track : Face Again
#
#
#
# Artist : King Krule Track : The Noose of Jah City
#
#
#
# Artist : How To Dress Well Track : Face Again
#
#
#
# ...
#
#
#
# Artist : Miranda Boumedin Track : Rosemary's Baby Theme
#
#
#
# Artist : Erik Satie Track : Gnossienne No. 1 (Arr. Kleynjans)
#
#
#
# Artist : Daniel Kaede Track : Yellow Hills
#
#
#
# Artist : Marcel Depuis Track : Pavane, Op. 50
#
#
#
# Artist : Manuel Boltano Track : A Field of Flowers
#
#
#
# Artist : Enrico Carmona Track : Braids
#
#
#
# Artist : Antoine Dufour Track : Hide and Seek
#
#
#
# Artist : Anila Mirela Track : Three Trees
#
#
#
# Artist : Kyle McEvoy Track : Hala
#
#
#
# Artist : John Hanks Track : Hills And Horizons
#
#
#
# Artist : John A. Nilson Track : Ave Nocturne
#
#
#
# Artist : Indigo Mazati Track : Ponte Veccio
#
#
#
# Artist : Vadim Cervenka Track : In My Garden
#
#
#
# Artist : Don Steale Track : Crying Hearts
#
#
#
# Artist : Gabriel Femi Track : Reflections
#
#
#
# Artist : Enrico Carmona Track : Tranceformation
#
#
#
# Artist : Sergei Baronin Track : Sweden
#
#
#
# Artist : Agustín Barrios Mangoré Track : Canción de Cuna
#
#
#
# Artist : Tom Ellenhag Track : Whispers
#
#
#
# Artist : Sergei Baronin Track : Mad World
#
#
#
# Artist : Francisco Tárrega Track : Adelita
#
#
#
# Artist : Richard Mollenbeck Track : Air on a G String
#
#
#
# Artist : Maneli Jamal Track : We Made It
#
#
#
# Artist : Channing Spence Track : Forevermore
#
#
#
# Artist : Henrik Janson Track : Laura Palmer's Theme
#
#
#
# Artist : Henrik Janson Track : Bibo No Aozora
#
#
#
# Artist : Sergei Baronin Track : May It Be
#
#
#
# Artist : Moldoni Track : Schindler's List
#
#
#
# Artist : Julyan Brynn Track : Shallow Waters
#
#
#
# Artist : Richard Mollenbeck Track : Adagio Albinoni
#
#
#
# Artist : Lance Allen Track : Rest Your Way Home
#
#
#
# Artist : Don Steale Track : My Deep Desolation
#
#
#
# Artist : Henrik Janson Track : Twin Peaks Theme
#
#
#
# Artist : Moldoni Track : Cornfield Chase
#
#
#
# Artist : Julyan Brynn Track : Svalbard
#
#
#
# Artist : Richard Mollenbeck Track : Gymnopedie
#
#
#
# Artist : Marcel Depuis Track : Sonata Pathétique
#
#
#
# Artist : Daniel Kaede Track : Northern
#
#
#
# Artist : Henrik Janson Track : Somewhere in Paris
#
#
#
# Artist : Miranda Boumedin Track : River Flows In You
#
#
#
# Artist : Cristopher Varela Track : Memories (Top Gun)
#
#
#
# Artist : Miguel Serugetti Track : Softly
#
#
#
# Artist : Indigo Mazati Track : La Storia D'Amor
#
#
#
# Artist : Hans Wolfgang Ziegler Track : Sunny & Cloudy
#
#
#
# Artist : Denis Turbide Track : Dimples
#
#
#
# Artist : Auguste Henrique Track : Mysterium
#
#
#
# Artist : Henrik Janson Track : Chi Mai
#
#
#
# Artist : Michel Legrand Track : The Summer Knows (Theme from "The Summer of '42')
#
#
#
# Artist : Christopher Varela Track : Deep Forest
#
#
#
# Artist : Hans Wolfgang Ziegler Track : Spring
#
#
#
# Artist : Daniel Kaede Track : Distant Fortune
#
#
#
# Artist : Al McCain Track : Magic Wind
#
#
#
# Artist : Pat Metheny Track : Cherish
#
#
#
# Artist : Cristopher Varela Track : The Ludlows
#
#
#
# Artist : Julyan Brynn Track : Floating Hearts
#
#
#
# Artist : Mauricio Galbardi Track : Porto Fino
#
#
#
# Artist : Mauricio Galbardi Track : Porto Fino
#
#
#
# Artist : Daniel Kaede Track : Distant Fortune
#
#
#
# Artist : Gabriel Femi Track : Reflections
#
#
#
# Artist : Michel Legrand Track : The Summer Knows (Theme from "The Summer of '42')
#
#
#
# Artist : Christian Rich Track : Face (feat. Denitia and Sene)
#
#
#
# Artist : Denitia and Sene Track : she's not the only one.
#
#
#
# Artist : Denitia and Sene Track : l.e.s. is more (interlude).
#
#
#
# Artist : Denitia and Sene Track : because we are fools.
#
#
#
# Artist : Denitia and Sene Track : because we are fools.
#
#
#
# Artist : Denitia Track : The Fan
#
#
#
# Artist : Brian Eno Track : An Ending (Ascent) - Remastered 2005
#
#
#
# Artist : Brian Eno Track : Taking Tiger Mountain - 2004 Digital Remaster
#
#
#
# Artist : Brian Eno Track : Slicing System
#
#
#
# Artist : Brian Eno Track : French Catalogues (Variation On 'The Canon In D Major' By Johann Pachelbel) - Remastered 2004
#
#
#
# Artist : Brian Eno Track : Small Craft on a Milk Sea
#
#
#
# Artist : Brian Eno Track : Becalmed - 2004 Remaster
#
#
#
# Artist : Denitia Track : Because We Are Fools
#
#
#
# Artist : Brian Eno Track : An Ending (Ascent) - Remastered 2005
#
#
#
# Artist : Brian Eno Track : Emerald and Stone
#
#
#
# Artist : Brian Eno Track : Signals - Remastered 2005
#
#
#
# Artist : Brian Eno Track : Stars - Remastered 2005
#
#
#
# Artist : Brian Eno Track : Drift - Remastered 2005
#
#
#
# Artist : Brian Eno Track : Lizard Point - Remastered 2004
#
#
#
# Artist : Brian Eno Track : A Clearing - Remastered 2004
#
#
#
# Artist : Brian Eno Track : Weightless - Remastered 2005
#
#
#
# Artist : Brian Eno Track : 1/1 - Remastered 2004
#
#
#
# Artist : Brian Eno Track : Emerald and Lime
#
#
#
# Artist : We Are KING Track : Hey
#
#
#
# Artist : Brian Eno Track : Reflection
#
#
#
# Artist : Brian Eno Track : Reflection
#
#
#
# Artist : Knowmadic Track : contact
#
#
#
# Artist : Boddhi Satva Track : Mama Kosa (Atjazz Astro Dub)
#
#
#
# Artist : Kelela Track : Blue Light
#
#
#
# Artist : Xavier Omär Track : Runnin' Round
#
#
#
# Artist : Knowmadic Track : contact
#
#
#
# Artist : DRWN. Track : Nuckles
#
#
#
# Artist : Lapalux Track : Holding On
#
#
#
# Artist : Denitia Track : Bound to Happen (Jubilee Remix)
#
#
#
# Artist : Jordan Rakei Track : Goodbyes
#
#
#
# Artist : Gabriel Garzón-Montano Track : My Balloon - Instrumental
#
#
#
# Artist : Laraaji Track : Change
#
#
#
# Artist : Balmorhea Track : Slow Stone
#
#
#
# Artist : This Patch of Sky Track : Paper Mountains
#
#
#
# Artist : Hidden Orchestra Track : East London Street - No Drums Version
#
#
#
# Artist : Bibio Track : PHANTOM BRICKWORKS III - Edit
#
#
#
# Artist : Gregg Kowalsky Track : L'Ambience, L'Orange
#
#
#
# Artist : Good Weather For An Airstrike Track : Every Day's New
#
#
#
# Artist : Stafrænn Hákon Track : Rafall
#
#
#
# Artist : Azaleh Track : Astral
#
#
#
# Artist : Azaleh Track : Astral
#
#
#
# Artist : Corre Track : Response
#
#
#
# Artist : Stafrænn Hákon Track : Rafall
#
#
#
# Artist : Gregg Kowalsky Track : L'Ambience, L'Orange
#
#
#
# Artist : Good Weather For An Airstrike Track : Every Day's New
#
#
#
# Artist : Hidden Orchestra Track : East London Street - No Drums Version
#
#
#
# Artist : Bibio Track : PHANTOM BRICKWORKS III - Edit
#
#
#
# Artist : Balmorhea Track : Slow Stone
#
#
#
# Artist : This Patch of Sky Track : Paper Mountains
#
#
#
# Artist : Gabriel Garzón-Montano Track : My Balloon - Instrumental
#
#
#
# Artist : Laraaji Track : Change
#
#
#
# Artist : Jordan Rakei Track : Goodbyes
#
#
#
# Artist : Denitia Track : Bound to Happen (Jubilee Remix)
#
#
#
# Artist : Denitia Track : Planes (Space People Remix)
#
#
#
# Artist : Denitia Track : trip.fall. - David Harness Vocal Mix
#
#
#
# Artist : Denitia Track : trip.fall. - David Harness Vocal Mix
#
#
#
# Artist : Joseph Shabason Track : Tite Cycle
#
#
#
# Artist : Claude Speeed Track : R U Sorry?
#
#
#
# Artist : Bonobo Track : Silver
#
#
#
# Artist : Bonobo Track : Sleepy Seven
#
#
#
# Artist : Bonobo Track : Black Sands
#
#
#
# Artist : Bonobo Track : Kerala
#
#
#
# Artist : Denitia Track : Planes
#
#
#
# Artist : Denitia Track : Planes (Space People Remix)
#
#
#
# Artist : Denitia Track : Planes
#
#
#
# Artist : BOSCO Track : Castles (feat. St. Beauty)
#
#
#
# Artist : Denitia and Sene Track : breathe.scream.dream.
#
#
#
# Artist : BOSCO Track : Castles (feat. St. Beauty)
#
#
#
# Artist : Denitia and Sene Track : breathe.scream.dream.
#
#
#
# Artist : Joseph Shabason Track : Smokestack
#
#
#
# Artist : Denitia Track : Because We Are Fools
#
#
#
# Artist : Moon Diagrams Track : Nightmoves
#
#
#
# Artist : House of Feelings Track : Falling (feat. Shamir)
#
#
#
# Artist : Moon Diagrams Track : Nightmoves
#
#
#
# Artist : House of Feelings Track : Falling (feat. Shamir)
#
#
#
# Artist : Moon Diagrams Track : Nightmoves
#
#
#
# Artist : Sudan Archives Track : Time
#
#
#
# Artist : Denitia Track : Ceilings
#
#
#
# Artist : Sudan Archives Track : Time
#
#
#
# Artist : Denitia Track : Ceilings
#
#
#
# Artist : Denitia Track : Ceilings
#
#
#
# Artist : Denitia Track : Planes (Space People Remix)
#
#
#
# Artist : Denitia Track : Bound to Happen
#
#
#
# Artist : Joseph Shabason Track : Aytche
#
#
#
# Artist : Art Feynman Track : Can’t Stand It
#
#
#
# Artist : a l l i e Track : Let Her
#
#
#
# Artist : Denitia Track : Fadin
#
#
#
# Artist : Scott Gilmore Track : Lady Street Racer
#
#
#
# Artist : House of Feelings Track : Falling (feat. Shamir)
#
#
#
# Artist : Denitia and Sene Track : casanova.
#
#
#
# Artist : Perera Elsewhere Track : Happened
#
#
#
# Artist : Katie Von Schleicher Track : Life's a Lie
#
#
#
# Artist : Denitia Track : Because We Are Fools
#
#
#
# Artist : Scott Gilmore Track : Subtle Vertigo
#
#
#
# Artist : Joseph Shabason Track : Looking Forward to Something, Dude
#
#
#
# Artist : a l l i e Track : Wildcat
#
#
#
# Artist : Fhloston Paradigm Track : ...The Storm
#
#
#
# Artist : Denitia Track : trip.fall. - UnHarness Yoself Instrumental
#
#
#
# Artist : Nocow Track : Moonlight Flit
#
#
#
# Artist : Denitia and Sene Track : breathe.scream.dream.
#
#
#
# Artist : Sontag Shogun Track : no.19 (Patient Elegy for Bernr'd Hoffmann)
#
#
#
# Artist : Amber Coffman Track : If You Want My Heart
#
#
#
# Artist : Cory Reese Track : Be Still, My Soul
#
#
#
# Artist : Cory Reese Track : Come Thou Fount of Every Blessing
#
#
#
# Artist : Cory Reese Track : Sweet Hour of Prayer
#
#
#
# Artist : Cory Reese Track : There Is a Green Hill Far Away
#
#
#
# Artist : Cory Reese Track : I Stand All Amazed
#
#
#
# Artist : Cory Reese Track : Believe
#
#
#
# Artist : Cory Reese Track : All Creatures of Our God and King
#
#
#
# Artist : Cory Reese Track : If You Could Hie to Kolob
#
#
#
# Artist : Cory Reese Track : Abide With Me; 'Tis Eventide
#
#
#
# Artist : Cory Reese Track : Celebration of Life
#
#
#
# Artist : Cory Reese Track : How Great Thou Art
#
#
#
# Artist : Cory Reese Track : Battle Hymn of the Republic
#
#
#
# Artist : Cory Reese Track : After The Rain
#
#
#
# Artist : Cory Reese Track : You Will Soar
#
#
#
# Artist : Cory Reese Track : Light Of Hope
#
#
#
# Artist : Cory Reese Track : Morning Glow
#
#
#
# Artist : Cory Reese Track : Live The Life
#
#
#
# Artist : Cory Reese Track : Epic
#
#
#
# Artist : Cory Reese Track : Open My Heart
#
#
#
# Artist : Cory Reese Track : Variations On Für Elise
#
#
#
# Artist : Cory Reese Track : Little Star
#
#
#
# Artist : Cory Reese Track : Looking In
#
#
#
# Artist : Cory Reese Track : Missing You
#
#
#
# Artist : Cory Reese Track : Heart to Heart
#
#
#
# Artist : Cory Reese Track : Black And White
#
#
#
# Artist : Cory Reese Track : Summer's Wind
#
#
#
# Artist : Cory Reese Track : Variations On Pachelbel's Canon In D
#
#
#
# Artist : Cory Reese Track : Whisper Of Angels
#
#
#
# Artist : Cory Reese Track : Footprints
#
#
#
# Artist : Cory Reese Track : Lullaby
#
#
#
# Artist : Cory Reese Track : Butterfly
#
#
#
# Artist : Cory Reese Track : Daybreak
#
#
#
# Artist : Cory Reese Track : When You Come
#
#
#
# Artist : Cory Reese Track : Moment Of Peace
#
#
#
# Artist : Cory Reese Track : Gift Of May
#
#
#
# Artist : Cory Reese Track : Dancing On The Stars
#
#
#
# Artist : Cory Reese Track : Window To Tomorrow
#
#
#
# Artist : Cory Reese Track : Starting Over
#
#
#
# Artist : Cory Reese Track : On My Mind
#
#
#
# Artist : Cory Reese Track : Broken Sky
#
#
#
# Artist : Cory Reese Track : The Purpose Of It All
#
#
#
# Artist : Cory Reese Track : What Child Is This
#
#
#
# Artist : Cory Reese Track : The Gift
#
#
#
# Artist : Cory Reese Track : Far, Far Away On Judea's Plain
#
#
#
# Artist : Cory Reese Track : The First Noel
#
#
#
# Artist : Cory Reese Track : O Holy Night
#
#
#
# Artist : Cory Reese Track : Oh Come All Ye Faithful
#
#
#
# Artist : Cory Reese Track : Silent Night
#
#
#
# Artist : Cory Reese Track : We Three Kings
#
#
#
# Artist : Cory Reese Track : Away In A Manger
#
#
#
# Artist : David Tolk Track : Grace
#
#
#
# Artist : David Tolk Track : Beautiful Savior/For the Beauty of the Earth
#
#
#
# Artist : David Tolk Track : For Lisa
#
#
#
# Artist : David Tolk Track : Redeemer of Israel
#
#
#
# Artist : David Tolk Track : Coming Home
#
#
#
# Artist : David Tolk Track : Amazing Grace (Solo Piano)
#
#
#
# Artist : David Tolk Track : Autumn Road
#
#
#
# Artist : David Tolk Track : I Need Thee Every Hour
#
#
#
# Artist : David Tolk Track : Revelation
#
#
#
# Artist : David Tolk Track : Be Still My Soul
#
#
#
# Artist : David Tolk Track : The Woods
#
#
#
# Artist : David Tolk Track : In Reverence
#
#
#
# Artist : David Tolk Track : Abide With Me
#
#
#
# Artist : David Tolk Track : Autumn Gold
#
#
#
# Artist : David Tolk Track : Simple Gifts
#
#
#
# Artist : David Tolk Track : The Garden
#
#
#
# Artist : David Tolk Track : Oh How Lovely Was The Morning
#
#
#
# Artist : David Tolk Track : God Be With You Till We Meet Again
#
#
#
# Artist : David Tolk Track : Come Thou Fount of Every Blessing
#
#
#
# Artist : David Tolk Track : A Poor Wayfaring Man of Grief
#
#
#
# Artist : David Tolk Track : Il est Ne le Divin Enfant
#
#
#
# Artist : David Tolk Track : Through Her Eyes
#
#
#
# Artist : David Tolk Track : By the Hearth
#
#
#
# Artist : David Tolk Track : Silent Night
#
#
#
# elapsed minutes = 0.12094735701878866

# %%
stmt = select(spotify_table)

# %% [markdown]
# # Spotify Web API

# %%
# Function 
def get_token():
    # Create authorization string 
    auth_string = client_id + ":" + client_secret
    auth_bytes = auth_string.encode("utf-8")
    auth_base64 = str(base64.b64encode(auth_bytes), "utf-8")

    url = "https://accounts.spotify.com/api/token"
    headers = {
        "Authorization": "Basic " + auth_base64,
        "Content-Type": "application/x-www-form-urlencoded"
    }
    data = {"grant_type": "client_credentials"}
    result = requests.post(url, headers=headers, data=data)
    json_result = json.loads(result.content)
    token = json_result["access_token"]
    return token

# Get token to use in headers
token = get_token()
print(token)
# Out:
# BQBR7WRc28SEbPOryMx7EcvMsyPCKUg3A9pJX1RhQPREkUjSuHwDAiI8XRS8Fk4W5r7zODmkTUBpDOzi53HjQ44qE1j5JaVUEPLe5c7RPsmMIAGyCL7pAbvTtrb22erkbzFbvl-qJUc

# %%
def get_auth_header(token):
    return {"Authorization": "Bearer " + token}

# %%
# Function to search for an artist
def search_for_artist(token, artist_name):
    url = "https://api.spotify.com/v1/search"
    headers = get_auth_header(token)
    # Construct query
    #query = f"q={artist_name}&type=artist,track"
    # Limit the query to top matching artist using 'limit=1'
    query = f"?q={artist_name}&type=artist&limit=1"

    query_url = url + query
    result = requests.get(query_url, headers=headers)
    json_result = json.loads(result.content)["artists"]["items"]
    if len(json_result) == 0:
        print("No artist found")
        return None
    return json_result[0]

# %%
def get_songs_by_artist(token, artist_id):
    # Required to pass some country code, (any country code)
    url = f"https://api.spotify.com/v1/artists/{artist_id}/top-tracks?country=US"
    headers = get_auth_header(token)
    result = requests.get(url, headers=headers)
    json_result = json.loads(result.content)["tracks"]
    return json_result

# %%
token = get_token()
result = search_for_artist(token, "Green Piccolo")
# print(result["name"])
artist_id = result["id"]
songs = get_songs_by_artist(token, artist_id)

display(JSON(songs, expanded=False))
# print(songs)

# %%
for idx, song in enumerate(songs):
    print(f"{idx + 1}")
    print(f"{song[0]}")

# %%
type(songs[0].keys())
# Out:
# dict_keys

# %%
for idx, song in enumerate(songs):
    print(f"Index {idx}: {song['name']}")
# Out:
# Index 0: Namek
# Index 1: Ain't Shit Free
# Index 2: robbery
# Index 3: Cosmic Vibes
# Index 4: witchcraft
# Index 5: traplord
# Index 6: OCB
# Index 7: Soul Searching
# Index 8: Damn!
# Index 9: Ride With Me
